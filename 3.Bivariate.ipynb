# %%
import pandas as pd

# %%
dataset=pd.read_csv("Preplacementdata.csv")

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4      5.0  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  215.0  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
dataset.cov()
# Out:
#                  sl_no          ssc_p          hsc_p       degree_p  \
# sl_no      3870.000000     -52.641355     -58.106028     -40.413645
# ssc_p       -52.641355     117.228377      60.348373      42.897137
# hsc_p       -58.106028      60.348373     118.755706      34.819820
# degree_p    -40.413645      42.897137      34.819820      54.151103
# etest_p      52.556168      37.659225      35.461678      21.929469
# mba_p         8.102336      24.535952      22.555846      17.272020
# salary    24490.654206  901754.893936  763359.777657  465131.504238
#
#                 etest_p          mba_p        salary
# sl_no         52.556168       8.102336  2.449065e+04
# ssc_p         37.659225      24.535952  9.017549e+05
# hsc_p         35.461678      22.555846  7.633598e+05
# degree_p      21.929469      17.272020  4.651315e+05
# etest_p      176.251018      16.886973  3.842344e+05
# mba_p         16.886973      34.028376  1.262455e+05
# ...

# %%
# What is the covariance between degree_p and etest_p?
# Positive covariance between these two,Both are positively differ by 21.9 

# What is the covariance between etest_p and mba_p?
# Positive covariance between these two,Both are positively differ by 16.8

# %%
dataset.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
# What is the correlation between salary and mba_p?
# Low degree of positve correlation between two,both are positively correlate by 0.139

# %%
dataset.drop('sl_no',inplace=True,axis=1)

# %%
dataset
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0    67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1    79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2    65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3    56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4    85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...       ...      ...    ...       ...    ...      ...
# 210  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(dataset)

# %%
# variance inflation factor is imported from the satsmodels.stats.outliers_influence module

from statsmodels.stats.outliers_influence import variance_inflation_factor

# Create a function named as calc_vif(X),X is the input variable

def calc_vif(X):
    
    #calculating VIF,DataFrame is created and stiord in ithe name vif
    vif=pd.DataFrame()
# Input column index names tabulted as variables name
    vif["variables"]=X.columns
# By uuing the for loop each and every coumn values of the input columns assigned in the name i 
# and find the vif by using x.values.
    vif["VIF"]=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
    return(vif)

# %%
#!pip install statsmodels

# %%
calc_vif(dataset[["ssc_p","hsc_p","etest_p","salary"]])
# Out:
#   variables        VIF
# 0     ssc_p  50.882683
# 1     hsc_p  46.172262
# 2   etest_p  27.747663
# 3    salary   3.346049

# %% [markdown]
# # Independant Sample - Unpaired T_Test
# # Different Group(Male,Female) but same Condition(salary)

# %%
dataset[dataset['gender']=='M']["salary"]
# Out:
# 0      270000.0
# 1      200000.0
# 2      250000.0
# 3           0.0
# 4      425000.0
#          ...
# 209    216000.0
# 210    400000.0
# 211    275000.0
# 212    295000.0
# 214         0.0
# Name: salary, Length: 139, dtype: float64

# %%
dataset[dataset['gender']=='F']["salary"]
# Out:
# 6           0.0
# 12          0.0
# 13     218000.0
# 15     200000.0
# 17          0.0
#          ...
# 197    260000.0
# 198         0.0
# 204    210000.0
# 208         0.0
# 213    204000.0
# Name: salary, Length: 76, dtype: float64

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
male=dataset[dataset['gender']=="M"]['salary']
female=dataset[dataset['gender']=='F']['salary']
ttest_ind(male,female)
# Out:
# Ttest_indResult(statistic=2.1103433958668765, pvalue=0.03599560646745178)

# %%
dataset[dataset['hsc_b']=="Others"]['salary']
# Out:
# 0      270000.0
# 1      200000.0
# 5           0.0
# 6           0.0
# 12          0.0
#          ...
# 210    400000.0
# 211    275000.0
# 212    295000.0
# 213    204000.0
# 214         0.0
# Name: salary, Length: 131, dtype: float64

# %%
dataset[dataset['hsc_b']=="Central"]['salary']
# Out:
# 2      250000.0
# 3           0.0
# 4      425000.0
# 7      252000.0
# 8      231000.0
#          ...
# 195    275000.0
# 198         0.0
# 202    240000.0
# 206         0.0
# 209    216000.0
# Name: salary, Length: 84, dtype: float64

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
Others=dataset[dataset['hsc_b']=="Others"]['salary']
Central=dataset[dataset['hsc_b']=="Central"]['salary']
ttest_ind(Others,Central)
# Out:
# Ttest_indResult(statistic=0.1684880697892395, pvalue=0.8663592108619098)

# %% [markdown]
# # Dependant Sample - paired T_Test
#
# # Same Group (Male) but different Condition(ssc_p,hsc_p)

# %%
from scipy.stats import ttest_rel
# dataset=dataset.dropna()
male=dataset[dataset['gender']=="M"]['ssc_p']
male1=dataset[dataset['gender']=='M']['hsc_p']
ttest_rel(male,male1)
# Out:
# Ttest_relResult(statistic=0.6852881050898078, pvalue=0.49431164600731503)

# %%
from scipy.stats import ttest_rel
# dataset=dataset.dropna()
Commerce=dataset[dataset['hsc_s']=="Commerce"]['etest_p']
Commerce1=dataset[dataset['hsc_s']=='Commerce']['mba_p']
ttest_rel(Commerce,Commerce1)
# Out:
# Ttest_relResult(statistic=7.868552092606869, pvalue=2.462926468454984e-12)

# %% [markdown]
# # Hypothesis Testing

# %%
# Null hypothesis = There is no similarity between 1oth pass mark of male 12th pass mark of male.
# Alternate Hypothesis = There is similarity between 10th pass mark and 12th pass mark of male.

# %%
# Statement: Test whether SSC_p of male and HSC_P of male is same?
# There is similarity between these two

# %%
# Statement: Test hsc_s (commerce)  wrt etest_p and mba_p 
# There is similarity between these two

# %% [markdown]
# # Reject Null hypothesis p<0.05
# # Accept Null hypothesis and Reject Alternate hypothesis

# %% [markdown]
# # ANAVO : Analysis of Variance

# %%
# Oneway Classification

# %%
import scipy.stats as stats

stats.f_oneway(dataset['ssc_p'],dataset['hsc_p'],dataset['degree_p'])
# Out:
# F_onewayResult(statistic=0.6719700864663097, pvalue=0.5110602818995302)

# %%
# pvale=0.5 There is variance between these given columns

# %%
# Twoway Classification

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Fit the ANOVA model
model = ols("dataset['salary'] ~ dataset['ssc_p'] * dataset['hsc_p']", dataset).fit()

# Perform ANOVA test
aov_table = sm.stats.anova_lm(model, typ=2)

# %%
aov_table
# Out:
#                                          sum_sq     df          F  \
# dataset['ssc_p']                   6.527418e+11    1.0  40.876520
# dataset['hsc_p']                   2.183866e+11    1.0  13.675979
# dataset['ssc_p']:dataset['hsc_p']  5.463624e+10    1.0   3.421474
# Residual                           3.369380e+12  211.0        NaN
#
#                                          PR(>F)
# dataset['ssc_p']                   1.024900e-09
# dataset['hsc_p']                   2.770011e-04
# dataset['ssc_p']:dataset['hsc_p']  6.575197e-02
# Residual                                    NaN

# %%
# F value is higher than p value (PR>F) There is significance variance between ssc_p and salary also hsc_p and salary
# ssc_p and hsc_p There is no sigificance variance between these two
