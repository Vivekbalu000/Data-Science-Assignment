# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
# 1) Replace the non values,Ans Replaced by Zero because if I use central tendency salary will be filled with some value so 
# It will be shown Not placed students also getting salary.
# Delete the Entire Rows-67 Rows will be deleted so we cannot get the proper result
# Relaced by zero is the good on for replace the non values

# %%
dataset["salary"].fillna(0,inplace =True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
# How many of them not placed? Ans 67

# %%
dataset[dataset["status"]!='Placed']
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3        4      M   56.0  Central   52.0  Central   Science     52.00
# 5        6      M   55.0   Others   49.8   Others   Science     67.25
# 6        7      F   46.0   Others   49.2   Others  Commerce     79.00
# 9       10      M   58.0  Central   70.0  Central  Commerce     61.00
# 12      13      F   47.0  Central   55.0   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 198    199      F   67.0  Central   70.0  Central  Commerce     65.00
# 201    202      M   54.2  Central   63.0   Others   Science     58.00
# 206    207      M   41.0  Central   42.0  Central   Science     60.00
# 208    209      F   43.0  Central   60.0   Others   Science     65.00
# 214    215      M   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
dataset[dataset["status"]=='Not Placed']
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3        4      M   56.0  Central   52.0  Central   Science     52.00
# 5        6      M   55.0   Others   49.8   Others   Science     67.25
# 6        7      F   46.0   Others   49.2   Others  Commerce     79.00
# 9       10      M   58.0  Central   70.0  Central  Commerce     61.00
# 12      13      F   47.0  Central   55.0   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 198    199      F   67.0  Central   70.0  Central  Commerce     65.00
# 201    202      M   54.2  Central   63.0   Others   Science     58.00
# 206    207      M   41.0  Central   42.0  Central   Science     60.00
# 208    209      F   43.0  Central   60.0   Others   Science     65.00
# 214    215      M   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
# 3) Non Placement reason - They didnot perform in the interview upto the level

# %%
# 4) Relation between salary and mba_p

# %%
dataset.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
# Corelation between salary and mba_p =0.139,Low degree of Positive correlation

# %%
Placed=dataset[dataset["status"]=='Placed']

# %%
Placed
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
# 5) Specialization getting Min salary

# %%
Placed[Placed["specialisation"]=='Mkt&HR']["salary"].min()
# Out:
# 200000.0

# %%
Placed[Placed["specialisation"]=='Mkt&Fin']["salary"].min()
# Out:
# 200000.0

# %%
# 6) How many of them getting above 500000 salary? - 6

# %%
Placed[Placed["salary"]>=500000.0]['salary']
# Out:
# 77     500000.0
# 119    940000.0
# 150    690000.0
# 163    500000.0
# 174    500000.0
# 177    650000.0
# Name: salary, dtype: float64

# %%
Placed[Placed["salary"]>=500000.0]['salary'].count()
# Out:
# 6

# %%
# 7) Test the ANAVO between etest_p and mba_p

# %%
# Reject Null hypothesis p<0.05
# Accept Null hypothesis 
# Reject Alternate hypothesis
# H0 - There is no significance variation between two columns
# H1 - There is significance variation between two columns

# %%
import scipy.stats as stats

stats.f_oneway(dataset['etest_p'],dataset['mba_p'])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %%
# pvalue=4.6 more than 0.05 So There is significance variation between etest_p mark and mba_p mark

# %%
# 8) Test Similarity between degree_t(Sci&Tech) and specialisation(Mkt&HR)

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
degree=dataset[dataset['degree_t']=="Sci&Tech"]['salary']
specialisation=dataset[dataset['specialisation']=='Mkt&HR']['salary']
ttest_ind(degree,specialisation)
# Out:
# Ttest_indResult(statistic=2.692041243555374, pvalue=0.007897969943471179)

# %%
# Reject Null hypothesis p<0.05
# Accept Null hypothesis 
# Reject Alternate hypothesis
# H0 - There is no significance relation between two columns
# H1 - There is significance relation between two columns

# %%
# pvalue=0.007 less than 0.05 Accept Null Hypothesis So There is no significance relation between these two.

# %%
# 9) convert Normal Disribution to Standard Normal Distribution for Salary column

# %%
import seaborn as sns

# %%
sns.distplot(dataset["salary"])
# Out:
# C:\Users\Hi\anaconda3\envs\ven\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.

# %%
def get_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax=sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='red')
    pyplot.axvline(endrange,color='red')
    sample=dataset
    sample_mean=sample.mean()
    sample_std=sample.std()
    print('Mean=%.3f,Standard Deviation=%.3f'%(sample_mean,sample_std))
    dist=norm(sample_mean,sample_std)
    values=[value for value in range(startrange,endrange)]
    probabilities=[dist.pdf(value)for value in values]
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_probability(dataset["salary"],700000,900000)
# Out:
# C:\Users\Hi\anaconda3\envs\ven\lib\site-packages\ipykernel_launcher.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """
# Mean=198702.326,Standard Deviation=154780.927
# The area between range(700000,900000):0.0005973310593974868
# 0.0005973310593974868

# %%
# Probability distribution function of the salary range from 700000 to 900000 is zero

# %%
# 11)Test similarity between the degree_t(Sci&Tech) wrt etest_p and mba_p at significance level of 5% 
# (Make decision using Hypothesis test)

# %%
from scipy.stats import ttest_rel
# dataset=dataset.dropna()
Sci1=dataset[dataset['degree_t']=="Sci&Tech"]['etest_p']
Sci2=dataset[dataset['degree_t']=="Sci&Tech"]['mba_p']
ttest_rel(Sci1,Sci2)
# Out:
# Ttest_relResult(statistic=5.0049844583693615, pvalue=5.517920600505392e-06)

# %%
# Reject Null hypothesis p<0.05
# Accept Null hypothesis 
# Reject Alternate hypothesis
# H0 - There is no significance relation between two columns
# H1 - There is significance relation between two columns

# %%
# pvalue=5.51 Greaterthan 0.05 Reject Null Hypothesis and accept Alternate Hypothesis So 
# There is  significance relation between these two.

# %%
# 12) Which parameter is highly correlated with salary

# %%
dataset.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %%
# scc_p parameter is only corrlated just above 50%

# %%
# 13) Plot any useful graph and explain

# %%
import matplotlib.pyplot as plt
sns.jointplot(x='ssc_p',y='salary',data=dataset)
plt.show()

# %%
# In this graph ssc_p in X axis,salary in y axis
# We can see Histogram and scatter plot both at a time
# 50% to nearly 90% scored people got the salary between range 200000 to 400000
# 1% people got Max salary range above 800000
# 60% to 85% scored some people got salary range between 400000 to below 800000

# %%
sns.distplot(dataset['degree_p'],hist=True,kde=True,kde_kws={'color':'red'})
# Out:
# C:\Users\Hi\anaconda3\envs\ven\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.

# %%
# In this diagram we can find kistogram and density curve of the degree_p.
# In kistogram we can see more people scored 63% to 67%
# Depends upon frequency density curve formed.
